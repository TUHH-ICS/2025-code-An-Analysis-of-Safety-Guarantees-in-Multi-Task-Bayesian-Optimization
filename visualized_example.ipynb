# %%
#!/usr/bin/env python3

"""
This script performs online visualization of the optimization process for one-dimensional problems using SaMSBO.

Functions:
    get_samples(gp, min_samples=50, num_samples=100, warmup_steps=100):
        Generates MCMC samples for the Gaussian Process (GP) model until a minimum number of samples is obtained.

Main Script:
    - Sets up the optimization problem using the LbSync function.
    - Defines the bounds and initial conditions for the optimization.
    - Samples initial points and evaluates them for all tasks.
    - Evaluates supplementary tasks and concatenates the data.
    - Standardizes the training targets.
    - Initializes the Bayesian Optimization loop.
    - Runs the optimization loop for a specified number of runs, updating the GP model and searching for new points in the safe region.
    - Plots the posterior distribution and prints the best value found during the optimization.
"""


import torch
from botorch.utils.transforms import unnormalize
import utils.utils
from utils.utils import standardize
from utils.utils import sample_from_task, concat_data, plot_post
from utils.mcmc_samples import get_mcmc_samples
import utils.get_robust_gp
from bo.bo_loop import BayesianOptimization
from utils.optim import optimize_gp
from utils.functions import LbSync
from math import ceil

torch.set_default_dtype(torch.float64)

def get_samples(gp, min_samples = 50, num_samples=100, warmup_steps=100):
    counter = 0
    samples, diagnostics = get_mcmc_samples(
        gp=gp, num_samples=num_samples, warmup_steps=warmup_steps
    )
    while samples["task_covar_module.covar_factor_prior"].shape[0] <= min_samples:
        if counter > 10:
            samples["task_covar_module.covar_factor_prior"] = (
                torch.eye(num_tsks).unsqueeze(0).repeat(2, 1, 1)
            )
            break
        samples0, diagnostics = get_mcmc_samples(
            gp=gp, num_samples=100, warmup_steps=100
        )
        samples = {
            key: torch.vstack((samples[key], samples0[key]))
            for key in samples.keys()
        }
        counter += 1
    return samples, diagnostics

delta_max = .15
dist = 0.3
num_tsks = 2
tau = 0.001
num_tsks = 2
num_lasers = 1
KType = "P"
obj = LbSync(
    Ktyp=KType, num_lasers=num_lasers, num_tsks=num_tsks, disturbance=dist
)
d = obj.dim
bounds = obj.bounds
obj.plot()
d = obj.dim
norm_bounds = torch.tensor([[0.0], [1.0]]).repeat(1,d)
# T = float(input("Enter threshold: "))
T = -18
tasks = [0,1]

nruns = 20 # number of optimization runs
num_sup_task_samples = 3*d
pot_start, _, pot_start_targets = sample_from_task(obj,[0],norm_bounds, n=128)
ind = pot_start_targets[pot_start_targets.squeeze()>=0.9*T].squeeze().argmin()

norm_x0 = pot_start[pot_start_targets.squeeze()>=0.9*T][ind,...].view(1,d)
tasks = list(range(num_tsks))
num_sup_task_samples = ceil(2 * d / (num_tsks - 1))
num_acq_samps = [1]
for _ in range(num_tsks - 1):
    num_acq_samps.append(num_sup_task_samples)


# evalaute initial point for all tasks
train_targets = torch.zeros(num_tsks, 1)
for j in range(num_tsks):
    train_targets[j, ...] = obj.f(norm_x0, j)
train_tasks = torch.arange(num_tsks).unsqueeze(-1)
norm_train_inputs = norm_x0.repeat(num_tsks, 1)

# evalaute supplementary tasks
for k in range(1, num_tsks):
    x, t, y = sample_from_task(
        obj,
        [k],
        norm_bounds + torch.tensor([[obj.max_disturbance], [-obj.max_disturbance]]),
        n=2 * num_sup_task_samples,
    )
    norm_train_inputs, train_tasks, train_targets = concat_data(
        (x, t, y), (norm_train_inputs, train_tasks, train_targets)
    )

norm_train_targets, mu, std = standardize(train_targets, train_task=train_tasks)
T_stdizd, _, _ = standardize(T, mu, std)
bo = BayesianOptimization(
    obj, tasks, norm_bounds, T_stdizd, (mu, std), num_acq_samps
)
gp = utils.utils.build_mtgp(
    (norm_train_inputs, train_tasks),
    norm_train_targets)
covar = torch.zeros(nruns, num_tsks, num_tsks)
beta_ = torch.zeros(nruns)
mod_runs = 5
for run in range(nruns):
    if run >= 45:
        bo.num_acq_samps = [1] * num_tsks
        mod_runs = 15
    if run <= 10 or run % mod_runs == 0:
        repeat = True
        while repeat:
            gp,_,_ = optimize_gp(
                gp, mode=1, max_iter=200)  # get MAP estimate
            mu = [
                gp.mean_module.base_means[r].constant.detach()
                for r in range(num_tsks)
            ]
            noise = gp.likelihood.noise.detach()
            varf = gp.covar_module.outputscale.detach()

            samples,_ = get_samples(gp, min_samples=50, num_samples=100, warmup_steps=100)

            sample_models = utils.utils.build_mtgp(
                (norm_train_inputs, train_tasks),
                norm_train_targets
            )
            sample_models.likelihood.noise = noise
            sample_models.task_covar_module.add_prior()
            sample_models.pyro_load_from_samples(samples)

            gp = utils.utils.build_mtgp(
                (norm_train_inputs, train_tasks),
                norm_train_targets,
                mu=mu,
            )
            # gp.likelihood.noise = noise
            robust_gp, sqrtbeta = utils.get_robust_gp.bayesian_robust_gp(
                sample_models, gp, norm_bounds, delta_max=delta_max, tau=tau
            )
            noise = robust_gp.likelihood.noise.detach()
            del sample_models
            repeat = (
                torch.sqrt(varf - varf**2 / (varf + noise)) * sqrtbeta
            ) >= abs(T_stdizd)
    else:
        gp,_,_ = optimize_gp(
            gp, mode=1, max_iter=200)  # get MAP estimate
        mu = [gp.mean_module.base_means[r].constant.detach() for r in range(num_tsks)]
        covar_chol = robust_gp.task_covar_module.covar_factor
        robust_gp = utils.utils.build_mtgp(
            (norm_train_inputs, train_tasks), norm_train_targets, mu=mu)
        robust_gp.task_covar_module._set_covar_factor(covar_chol)
    covar[run, ...] = robust_gp.task_covar_module._eval_covar_matrix()
    beta_[run] = sqrtbeta
    bo.update_gp(robust_gp, sqrtbeta)
    norm_train_inputs, train_tasks, norm_train_targets = bo.step()
    T_stdizd = bo.threshold
    plot_post(robust_gp,[0],torch.linspace(0,1,100),sqrtbeta,T_stdizd)
    gp = utils.utils.build_mtgp(
        (norm_train_inputs, train_tasks), norm_train_targets, mu=mu)
# add data
train_inputs = unnormalize(norm_train_inputs, bounds)
train_targets = bo.unstd_train_targets
print(
    f"Best value: {round(bo.best_y[-1],3)} at input: {unnormalize(bo.best_x[-1],bounds).round(decimals=3)}"
)
# Out:
# Std: tensor([[2.9729]])
# Mean: tensor([-13.9502,  -4.7172])
#
# Final loss: 1.290303370671803, Outputscale: 3.0350813997962773, Correlation: tensor([[1.0000, 0.9900],
#         [0.9900, 1.0000]]), Lengthscales: tensor([[0.2052]], grad_fn=<SoftplusBackward0>)
# Sample: 100%|██████████| 200/200 [00:12, 15.86it/s, step size=9.33e-01, acc. prob=0.846]
# Sample: 100%|██████████| 200/200 [00:15, 12.74it/s, step size=4.34e-01, acc. prob=0.962]
# 100%|██████████| 65/65 [00:00<00:00, 325.35it/s]
# /home/jannis/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:284: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(
# Norm difference of posterior means: 3005.072002010922
# Correlation Matrix: tensor([[1.0000, 0.9993],
#         [0.9993, 1.0000]])
# Uncertainty at supplementary task: 1.9652167916861265
# lambda:12.162816514915463
# gamma: 9.345782137895451
# sqrtbeta: 51.37920342480533
# Run :  1
# Best value found: -13.950
# Worst value: -13.950212097729551
# New Point: tensor([[0.7550]])
# Std: tensor([[2.8314]])
# Mean: tensor([-10.4570,  -4.2770])
# Final loss: 0.30766587618191876, Outputscale: 1.3865396374637387, Correlation: tensor([[1.0000, 0.9900],
#         [0.9900, 1.0000]]), Lengthscales: tensor([[0.1708]], grad_fn=<SoftplusBackward0>)
# Sample: 100%|██████████| 200/200 [00:12, 16.00it/s, step size=8.38e-01, acc. prob=0.881]
# 100%|██████████| 100/100 [00:00<00:00, 236.16it/s]
# /home/jannis/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:284: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(
# Norm difference of posterior means: 3400.3561750986173
# Correlation Matrix: tensor([[1.0000, 0.9994],
#         [0.9994, 1.0000]])
# Uncertainty at supplementary task: 1.1446443460420364
# lambda:17.409337386236707
# gamma: 3.7087527164841565
# sqrtbeta: 32.971853111164556
# Run :  2
# Best value found: -6.964
# Worst value: -13.950212097729551
# /home/jannis/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/botorch/optim/optimize.py:359: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 8 and message Positive directional derivative for linesearch.'), UserWarning('SLSQP failed to converge to a solution the satisfies the non-linear constraints. Returning the feasible starting point.'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 8 and message Positive directional derivative for linesearch.'), UserWarning('SLSQP failed to converge to a solution the satisfies the non-linear constraints. Returning the feasible starting point.')]
# Because you specified `batch_initial_conditions`, optimization will not be retried with new initial conditions and will proceed with the current solution. Suggested remediation: Try again with different `batch_initial_conditions`, or don't provide `batch_initial_conditions.`
#   warnings.warn(first_warn_msg, RuntimeWarning)
# New Point: tensor([[0.9116]])
# Std: tensor([[2.4634]])
# Mean: tensor([-10.1331,  -4.3871])
# Final loss: 0.47853713125804287, Outputscale: 4.6922021795999855, Correlation: tensor([[1.0000, 0.9900],
#         [0.9900, 1.0000]]), Lengthscales: tensor([[0.1727]], grad_fn=<SoftplusBackward0>)
# Sample: 100%|██████████| 200/200 [00:14, 14.01it/s, step size=6.03e-01, acc. prob=0.952]
# 100%|██████████| 100/100 [00:00<00:00, 280.70it/s]
# /home/jannis/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:284: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(
# Norm difference of posterior means: 12.453854077364914
# Correlation Matrix: tensor([[1.0000, 0.9457],
#         [0.9457, 1.0000]])
# Uncertainty at supplementary task: 2.348081942800103
# lambda:0.4550160023164903
# gamma: 1.6124413353717981
# sqrtbeta: 7.221076064966252
# Run :  3
# Best value found: -6.964
# Worst value: -13.950212097729551
# New Point: tensor([[0.5783]])
# Std: tensor([[2.3845]])
# Mean: tensor([-9.0699, -4.1072])
# Final loss: 0.07693097975382084, Outputscale: 6.287749515145965, Correlation: tensor([[1.0000, 0.9900],
#         [0.9900, 1.0000]]), Lengthscales: tensor([[0.1783]], grad_fn=<SoftplusBackward0>)
# Sample: 100%|██████████| 200/200 [00:13, 15.03it/s, step size=1.02e+00, acc. prob=0.922]
# 100%|██████████| 100/100 [00:00<00:00, 187.64it/s]
# /home/jannis/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:284: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(
# Norm difference of posterior means: 36.510634646359584
# Correlation Matrix: tensor([[1.0000, 0.9914],
#         [0.9914, 1.0000]])
# Uncertainty at supplementary task: 1.131042549544971
# lambda:0.0001
# gamma: 2.0534363418591437
# sqrtbeta: 8.616645184661344
# Run :  4
# Best value found: -5.880
# Worst value: -13.950212097729551
# New Point: tensor([[0.4884]])
# Std: tensor([[2.2732]])
# Mean: tensor([-8.3819, -3.9462])
# Final loss: -0.3019814770652751, Outputscale: 6.237269943305594, Correlation: tensor([[1.0000, 0.9900],
#         [0.9900, 1.0000]]), Lengthscales: tensor([[0.1667]], grad_fn=<SoftplusBackward0>)
# Sample: 100%|██████████| 200/200 [00:11, 16.95it/s, step size=9.41e-01, acc. prob=0.900]
# 100%|██████████| 100/100 [00:00<00:00, 241.40it/s]
# /home/jannis/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:284: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(
# Norm difference of posterior means: 17.63689756252628
# Correlation Matrix: tensor([[1.0000, 0.9952],
#         [0.9952, 1.0000]])
# Uncertainty at supplementary task: 0.8524160635559582
# lambda:0.0001
# gamma: 2.0704024796946374
# sqrtbeta: 8.687837794964699
# Run :  5
# Best value found: -5.630
# Worst value: -13.950212097729551
# New Point: tensor([[0.4406]])
# Std: tensor([[2.1822]])
# Mean: tensor([-7.9121, -3.8981])
# Final loss: -0.2545834141723067, Outputscale: 6.348267465238036, Correlation: tensor([[1.0000, 0.9900],
#         [0.9900, 1.0000]]), Lengthscales: tensor([[0.1344]], grad_fn=<SoftplusBackward0>)
# Sample: 100%|██████████| 200/200 [00:15, 12.63it/s, step size=4.65e-01, acc. prob=0.985]
# 100%|██████████| 100/100 [00:00<00:00, 167.55it/s]
# /home/jannis/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:284: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(
# Norm difference of posterior means: 23.746178211571
# Correlation Matrix: tensor([[1.0000, 0.9943],
#         [0.9943, 1.0000]])
# Uncertainty at supplementary task: 0.899264828523377
# lambda:0.0001
# gamma: 1.9999574941351763
# sqrtbeta: 8.392239441739708
# Run :  6
# Best value found: -5.563
# Worst value: -13.950212097729551
# New Point: tensor([[0.4004]])
# Std: tensor([[2.0898]])
# Mean: tensor([-7.5739, -3.7631])
# Final loss: -0.5972004644397686, Outputscale: 6.61048672412158, Correlation: tensor([[1.0000, 0.9900],
#         [0.9900, 1.0000]]), Lengthscales: tensor([[0.1345]], grad_fn=<SoftplusBackward0>)
# Sample: 100%|██████████| 200/200 [00:09, 20.35it/s, step size=1.16e+00, acc. prob=0.780]
# 100%|██████████| 100/100 [00:00<00:00, 193.88it/s]
# /home/jannis/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:284: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(
# Norm difference of posterior means: 38.95922477328556
# Correlation Matrix: tensor([[1.0000, 0.9950],
#         [0.9950, 1.0000]])
# Uncertainty at supplementary task: 0.9542325019672941
# lambda:0.0001
# gamma: 2.2718204301559717
# sqrtbeta: 9.533019520725261
# Run :  7
# Best value found: -5.545
# Worst value: -13.950212097729551
# New Point: tensor([[0.4207]])
# Std: tensor([[2.0036]])
# Mean: tensor([-7.3208, -3.6572])
# Final loss: -0.9041282500632565, Outputscale: 6.713711324442521, Correlation: tensor([[1.0000, 0.9900],
#         [0.9900, 1.0000]]), Lengthscales: tensor([[0.1327]], grad_fn=<SoftplusBackward0>)
# Warmup:   6%|▌         | 11/200 [00:01,  9.53it/s, step size=1.74e-01, acc. prob=0.743]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 135
#     132 noise = gp.likelihood.noise.detach()
#     133 varf = gp.covar_module.outputscale.detach()
# --> 135 samples,_ = get_samples(gp, min_samples=50, num_samples=100, warmup_steps=100)
#     137 sample_models = utils.utils.build_mtgp(
#     138     (norm_train_inputs, train_tasks),
#     139     norm_train_targets
#     140 )
#     141 sample_models.likelihood.noise = noise
#
# Cell In[2], line 38, in get_samples(gp, min_samples, num_samples, warmup_steps)
#      36 def get_samples(gp, min_samples = 50, num_samples=100, warmup_steps=100):
#      37     counter = 0
# ---> 38     samples, diagnostics = get_mcmc_samples(
#      39         gp=gp, num_samples=num_samples, warmup_steps=warmup_steps
#      40     )
#      41     while samples["task_covar_module.covar_factor_prior"].shape[0] <= min_samples:
#      42         if counter > 10:
#
# File ~/Repos_Code_Papers/2025-code-an-analysis-of-safety-guarantees-in-multi-task-bayesian-optimization/utils/mcmc_samples.py:46, in get_mcmc_samples(gp, num_samples, warmup_steps)
#      42 nuts_kernel = NUTS(pyro_model, jit_compile=False, max_tree_depth=3, full_mass=True)
#      43 mcmc_run = MCMC(
#      44     nuts_kernel, num_samples=num_samples, warmup_steps=warmup_steps, disable_progbar=False
#      45 )
# ---> 46 mcmc_run.run(train_inputs, train_targets)
#      47 diagnostics = mcmc_run.diagnostics()
#      48 samp_temp = mcmc_run.get_samples()
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/poutine/messenger.py:12, in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/infer/mcmc/api.py:563, in MCMC.run(self, *args, **kwargs)
#     554 with optional(
#     555     pyro.validation_enabled(not self.disable_validation),
#     556     self.disable_validation is not None,
#    (...)
#     560     # This also resolves "RuntimeError: Cowardly refusing to serialize non-leaf tensor which
#     561     # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#     562     args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
# --> 563     for x, chain_id in self.sampler.run(*args, **kwargs):
#     564         if num_samples[chain_id] == 0:
#     565             num_samples[chain_id] += 1
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/infer/mcmc/api.py:223, in _UnarySampler.run(self, *args, **kwargs)
#     221 logger = initialize_logger(logger, "", progress_bar)
#     222 hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
# --> 223 for sample in _gen_samples(
#     224     self.kernel,
#     225     self.warmup_steps,
#     226     self.num_samples,
#     227     hook_w_logging,
#     228     i if self.num_chains > 1 else None,
#     229     *args,
#     230     **kwargs
#     231 ):
#     232     yield sample, i  # sample, chain_id
#     233 self.kernel.cleanup()
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/infer/mcmc/api.py:150, in _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs)
#     148 yield {name: params[name].shape for name in save_params}
#     149 for i in range(warmup_steps):
# --> 150     params = kernel.sample(params)
#     151     hook(
#     152         kernel,
#     153         params,
#     154         "Warmup [{}]".format(chain_id) if chain_id is not None else "Warmup",
#     155         i,
#     156     )
#     157 for i in range(num_samples):
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/infer/mcmc/nuts.py:452, in NUTS.sample(self, params)
#     450     z_right_grads = new_tree.z_right_grads
#     451 else:  # go the the left, start from the left leaf of current tree
# --> 452     new_tree = self._build_tree(
#     453         z_left,
#     454         r_left,
#     455         z_left_grads,
#     456         log_slice,
#     457         direction,
#     458         tree_depth,
#     459         energy_current,
#     460     )
#     461     z_left = new_tree.z_left
#     462     r_left = new_tree.r_left
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/infer/mcmc/nuts.py:259, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     254     return self._build_basetree(
#     255         z, r, z_grads, log_slice, direction, energy_current
#     256     )
#     258 # build the first half of tree
# --> 259 half_tree = self._build_tree(
#     260     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     261 )
#     262 z_proposal = half_tree.z_proposal
#     263 z_proposal_pe = half_tree.z_proposal_pe
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/infer/mcmc/nuts.py:254, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     250 def _build_tree(
#     251     self, z, r, z_grads, log_slice, direction, tree_depth, energy_current
#     252 ):
#     253     if tree_depth == 0:
# --> 254         return self._build_basetree(
#     255             z, r, z_grads, log_slice, direction, energy_current
#     256         )
#     258     # build the first half of tree
#     259     half_tree = self._build_tree(
#     260         z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     261     )
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/infer/mcmc/nuts.py:199, in NUTS._build_basetree(self, z, r, z_grads, log_slice, direction, energy_current)
#     197 def _build_basetree(self, z, r, z_grads, log_slice, direction, energy_current):
#     198     step_size = self.step_size if direction == 1 else -self.step_size
# --> 199     z_new, r_new, z_grads, potential_energy = velocity_verlet(
#     200         z,
#     201         r,
#     202         self.potential_fn,
#     203         self.mass_matrix_adapter.kinetic_grad,
#     204         step_size,
#     205         z_grads=z_grads,
#     206     )
#     207     r_new_unscaled = self.mass_matrix_adapter.unscale(r_new)
#     208     energy_new = potential_energy + self._kinetic_energy(r_new_unscaled)
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/ops/integrator.py:39, in velocity_verlet(z, r, potential_fn, kinetic_grad, step_size, num_steps, z_grads)
#      37 r_next = r.copy()
#      38 for _ in range(num_steps):
# ---> 39     z_next, r_next, z_grads, potential_energy = _single_step_verlet(
#      40         z_next, r_next, potential_fn, kinetic_grad, step_size, z_grads
#      41     )
#      42 return z_next, r_next, z_grads, potential_energy
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/ops/integrator.py:61, in _single_step_verlet(z, r, potential_fn, kinetic_grad, step_size, z_grads)
#      58 for site_name in z:
#      59     z[site_name] = z[site_name] + step_size * r_grads[site_name]  # z(n+1)
# ---> 61 z_grads, potential_energy = potential_grad(potential_fn, z)
#      62 for site_name in r:
#      63     r[site_name] = r[site_name] + 0.5 * step_size * (-z_grads[site_name])  # r(n+1)
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/ops/integrator.py:83, in potential_grad(potential_fn, z)
#      81     node.requires_grad_(True)
#      82 try:
# ---> 83     potential_energy = potential_fn(z)
#      84 # handle exceptions as defined in the exception registry
#      85 except Exception as e:
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/infer/mcmc/util.py:278, in _PEMaker._potential_fn(self, params)
#     276 params_constrained = {k: self.transforms[k].inv(v) for k, v in params.items()}
#     277 cond_model = poutine.condition(self.model, params_constrained)
# --> 278 model_trace = poutine.trace(cond_model).get_trace(
#     279     *self.model_args, **self.model_kwargs
#     280 )
#     281 log_joint = self.trace_prob_evaluator.log_prob(model_trace)
#     282 for name, t in self.transforms.items():
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/poutine/trace_messenger.py:198, in TraceHandler.get_trace(self, *args, **kwargs)
#     190 def get_trace(self, *args, **kwargs):
#     191     """
#     192     :returns: data structure
#     193     :rtype: pyro.poutine.Trace
#    (...)
#     196     Calls this poutine and returns its trace instead of the function's return value.
#     197     """
# --> 198     self(*args, **kwargs)
#     199     return self.msngr.get_trace()
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/poutine/trace_messenger.py:174, in TraceHandler.__call__(self, *args, **kwargs)
#     170 self.msngr.trace.add_node(
#     171     "_INPUT", name="_INPUT", type="args", args=args, kwargs=kwargs
#     172 )
#     173 try:
# --> 174     ret = self.fn(*args, **kwargs)
#     175 except (ValueError, RuntimeError) as e:
#     176     exc_type, exc_value, traceback = sys.exc_info()
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/poutine/messenger.py:12, in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/poutine/messenger.py:12, in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/pyro/poutine/messenger.py:12, in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#
# File ~/Repos_Code_Papers/2025-code-an-analysis-of-safety-guarantees-in-multi-task-bayesian-optimization/utils/mcmc_samples.py:37, in get_mcmc_samples.<locals>.pyro_model(x, y)
#      35 def pyro_model(x, y):
#      36     with gpytorch.settings.fast_computations(False, False, False):
# ---> 37         sampled = gppyro.pyro_sample_from_prior()
#      38         output = sampled.likelihood(sampled(x))
#      39         pyro.sample("obs", output, obs=y.squeeze())
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/module.py:386, in Module.pyro_sample_from_prior(self)
#     378 def pyro_sample_from_prior(self):
#     379     """
#     380     For each parameter in this Module and submodule that have defined priors, sample a value for that parameter
#     381     from its corresponding prior with a pyro.sample primitive and load the resulting value in to the parameter.
#    (...)
#     384     parameters of the model that have GPyTorch priors registered to them.
#     385     """
# --> 386     new_module = self.to_pyro_random_module()
#     387     return _pyro_sample_from_prior(module=new_module, memo=None, prefix="")
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/module.py:361, in Module.to_pyro_random_module(self)
#     360 def to_pyro_random_module(self):
# --> 361     return self.to_random_module()
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/module.py:374, in Module.to_random_module(self)
#     372 for mname, child in new_module.named_children():
#     373     if isinstance(child, Module):
# --> 374         setattr(new_module, mname, child.to_random_module())
#     376 return new_module
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/gpytorch/module.py:366, in Module.to_random_module(self)
#     364 random_module_cls = type("_Random" + self.__class__.__name__, (RandomModuleMixin, self.__class__), {})
#     365 if not isinstance(self, random_module_cls):
# --> 366     new_module = copy.deepcopy(self)
#     367     new_module.__class__ = random_module_cls  # hack
#     368 else:
#     369     # Unclear if this branch would ever get used in practice, but it semantically makes sense to have.
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/copy.py:143, in deepcopy(x, memo, _nil)
#     141 copier = getattr(x, "__deepcopy__", None)
#     142 if copier is not None:
# --> 143     y = copier(memo)
#     144 else:
#     145     reductor = dispatch_table.get(cls)
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/torch/_tensor.py:121, in Tensor.__deepcopy__(self, memo)
#     112         raise RuntimeError(
#     113             "The default implementation of __deepcopy__() for wrapper subclasses "
#     114             "only works for subclass types that implement clone() and for which "
#    (...)
#     118             "different type."
#     119         )
#     120 else:
# --> 121     new_storage = self._typed_storage()._deepcopy(memo)
#     122     if self.is_quantized:
#     123         # quantizer_params can be different type based on torch attribute
#     124         quantizer_params: Union[
#     125             Tuple[torch.qscheme, float, int],
#     126             Tuple[torch.qscheme, Tensor, Tensor, int],
#     127         ]
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/torch/_tensor.py:253, in Tensor._typed_storage(self)
#     251 def _typed_storage(self):
#     252     untyped_storage = self.untyped_storage()
# --> 253     return torch.TypedStorage(
#     254         wrap_storage=untyped_storage, dtype=self.dtype, _internal=True
#     255     )
#
# File ~/.pyenv/versions/3.12.8/envs/mtbo/lib/python3.12/site-packages/torch/storage.py:691, in TypedStorage.__new__(cls, wrap_storage, dtype, device, _internal, *args)
#     686     raise RuntimeError(
#     687         "Only child classes of _LegacyStorage can be instantiated"
#     688     )
#     690 if cls == TypedStorage:
# --> 691     return super().__new__(cls)
#     693 else:
#     694     arg_error_msg = (
#     695         f"{cls}.__new__ received an invalid combination "
#     696         f"of arguments. Expected one of:\n"
#    (...)
#     700         " * (*, UntypedStorage wrap_storage)"
#     701     )
#
# KeyboardInterrupt:
# Warmup:   6%|▌         | 12/200 [00:11,  9.53it/s, step size=3.26e-01, acc. prob=0.764]
